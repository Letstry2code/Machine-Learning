# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url='https://raw.githubusercontent.com/digipodium/Datasets/main/sample_data.csv'
df=pd.read_csv(url)
df.head()
# Out:
#    country    salary   age happy
# 0  germany   49000.0  35.0   yes
# 1    spain   10000.0   NaN    no
# 2    italy  230000.0  39.0    no
# 3    spain  200000.0  30.0   yes
# 4    italy       NaN  30.0   yes

# %% [markdown]
# ## How to drop columns

# %%
df.drop(columns=['country'])   ## Fake Drop, add inplace = True to drop actually
# Out:
#       salary   age happy
# 0    49000.0  35.0   yes
# 1    10000.0   NaN    no
# 2   230000.0  39.0    no
# 3   200000.0  30.0   yes
# 4        NaN  30.0   yes
# 5    31000.0  23.0    no
# 6        NaN  34.0   yes
# 7   400000.0   NaN   yes
# 8   200000.0  29.0    no
# 9   340000.0  35.0   yes
# 10   30000.0  25.0   yes

# %% [markdown]
# Values to add,,, not used much,, add operation

# %%
val_to_add=[22,3,2,1,2,4,52,2,2,22,3]
df['new_col']=val_to_add
df
# Out:
#     country    salary   age happy  new_col
# 0   germany   49000.0  35.0   yes       22
# 1     spain   10000.0   NaN    no        3
# 2     italy  230000.0  39.0    no        2
# 3     spain  200000.0  30.0   yes        1
# 4     italy       NaN  30.0   yes        2
# 5     spain   31000.0  23.0    no        4
# 6   germany       NaN  34.0   yes       52
# 7     spain  400000.0   NaN   yes        2
# 8     italy  200000.0  29.0    no        2
# 9     italy  340000.0  35.0   yes       22
# 10  germany   30000.0  25.0   yes        3

# %% [markdown]
# ## for applying any kind of operation

# %%
df['salary_reduced']=df.salary.apply(lambda v:v//100)

# %%
df
# Out:
#     country    salary   age happy  new_col  salary_reduced
# 0   germany   49000.0  35.0   yes       22           490.0
# 1     spain   10000.0   NaN    no        3           100.0
# 2     italy  230000.0  39.0    no        2          2300.0
# 3     spain  200000.0  30.0   yes        1          2000.0
# 4     italy       NaN  30.0   yes        2             NaN
# 5     spain   31000.0  23.0    no        4           310.0
# 6   germany       NaN  34.0   yes       52             NaN
# 7     spain  400000.0   NaN   yes        2          4000.0
# 8     italy  200000.0  29.0    no        2          2000.0
# 9     italy  340000.0  35.0   yes       22          3400.0
# 10  germany   30000.0  25.0   yes        3           300.0

# %% [markdown]
# ### Imputer for missing data

# %%
from sklearn.impute import SimpleImputer

# %% [markdown]
# ## Creating Object

# %%
cols_to_impute=['salary','age','salary_reduced']
si=SimpleImputer()
df[cols_to_impute]=si.fit_transform(df[cols_to_impute])
df
# Out:
#     country         salary        age happy  new_col  salary_reduced
# 0   germany   49000.000000  35.000000   yes       22      490.000000
# 1     spain   10000.000000  31.111111    no        3      100.000000
# 2     italy  230000.000000  39.000000    no        2     2300.000000
# 3     spain  200000.000000  30.000000   yes        1     2000.000000
# 4     italy  165555.555556  30.000000   yes        2     1655.555556
# 5     spain   31000.000000  23.000000    no        4      310.000000
# 6   germany  165555.555556  34.000000   yes       52     1655.555556
# 7     spain  400000.000000  31.111111   yes        2     4000.000000
# 8     italy  200000.000000  29.000000    no        2     2000.000000
# 9     italy  340000.000000  35.000000   yes       22     3400.000000
# 10  germany   30000.000000  25.000000   yes        3      300.000000

# %% [markdown]
# ## Automobile DataSet PreProcessing

# %%
automobile_data_url='https://raw.githubusercontent.com/digipodium/Datasets/main/regression/automobile.csv'
df=pd.read_csv(automobile_data_url,index_col=0)  ## Setting Index

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
numerical_col=['normalized-losses','wheel-base','length','width','height','curb-weight','engine-size','bore','stroke','compression-ratio','horsepower','peak-rpm','city-mpg','highway-mpg','price']
categorical_col=['make','fuel-type','aspiration','num-of-doors','body-style','drive-wheels','engine-location','engine-type','num-of-cylinders','fuel-system']

# %%
# remove all ? from dataframe
df.replace('?',np.nan,inplace=True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
# numerical column with missing Values
df[numerical_col].isnull().sum()
# Out:
# normalized-losses    41
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-size           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
# Categorical
df[categorical_col].isnull().sum()
# Out:
# make                0
# fuel-type           0
# aspiration          0
# num-of-doors        2
# body-style          0
# drive-wheels        0
# engine-location     0
# engine-type         0
# num-of-cylinders    0
# fuel-system         0
# dtype: int64

# %%
num_col_with_na=['normalized-losses','bore','stroke','horsepower','peak-rpm']
cat_col_with_na=['num-of-doors']

# %%
##from sklearn.impute import SimpleImputer

# %%
 ### num_imp=SimpleImputer()
##cat_imp=SimpleImputer(strategy='most_frequent')

# %%
#df[num_col_with_na]=num_imp.fit_transform(df[num_col_with_na])

# %%
#df[cat_col_with_na]=cat_imp.fit_transform(df[cat_col_with_na])

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
# type of Values
#df[categorical_col].nunique()

# %% [markdown]
# # 2 Values only : Binary : Label Encoding

# %% [markdown]
# ## Label Encoding
# # > Ordinal .... Fit transform

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder,OneHotEncoder

# %%
#fuel_enc=LabelEncoder()
#df['fuel-type']=fuel_enc.fit_transform(df['fuel-type'])
#df['fuel-type']

# %%
#fuel_enc.classes_

# %%
#fuel_enc.transform(['gas','gas','diesel'])

# %%
#fuel_enc.inverse_transform([0,1,0])

# %%
#num-of-doors_enc=LabelEncoder()
#df['num-of-doors']=num-of-doors.fit_transform(df['num-of-doors'])
#df['num-of-doors']

# %%
binary_cols=['fuel-type','aspiration','num-of-doors','engine-location']
ordinal_enc=OrdinalEncoder()
df[binary_cols]=ordinal_enc.fit_transform(df[binary_cols])
df[categorical_col]
# Out:
#             make  fuel-type  aspiration  num-of-doors   body-style  \
# 0    alfa-romero        1.0         0.0           1.0  convertible
# 1    alfa-romero        1.0         0.0           1.0  convertible
# 2    alfa-romero        1.0         0.0           1.0    hatchback
# 3           audi        1.0         0.0           0.0        sedan
# 4           audi        1.0         0.0           0.0        sedan
# ..           ...        ...         ...           ...          ...
# 200        volvo        1.0         0.0           0.0        sedan
# 201        volvo        1.0         1.0           0.0        sedan
# 202        volvo        1.0         0.0           0.0        sedan
# 203        volvo        0.0         1.0           0.0        sedan
# 204        volvo        1.0         1.0           0.0        sedan
#
#     drive-wheels  engine-location engine-type num-of-cylinders fuel-system
# 0            rwd              0.0        dohc             four        mpfi
# ...

# %% [markdown]
# # One Hot Encoding checks unique columns
#
#
# >>>> Drop to avoid dummy value issues

# %%
make_enc=OneHotEncoder(drop='first')
make_dummies=make_enc.fit_transform(df[['make']]).toarray()
df=pd.concat([df,pd.DataFrame(make_dummies)],axis=1)

# %%
# Can drop only once

# df.drop(columns=['make'],inplace=True)
